# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
cafe = pd.read_csv("cafe.csv", encoding = "utf8")

# %%
cafe.head()
# Out:
#    Unnamed: 0    Title                      Address   Longitude   Latitude  \
# 0           0     카페이숲  충남 천안시 서북구 성거읍 남창마을1길 32 1층  127.195422  36.862185
# 1           1     블렌데렌     충남 천안시 동남구 먹거리8길 5 1, 2층         NaN        NaN
# 2           2  그리고스페셜티           충남 천안시 동남구 유량로 104  127.172754  36.807128
# 3           3     오월의숲            충남 천안시 서북구 세관길 78  127.145208  36.823195
# 4           4      유얼스          충남 천안시 서북구 불당31길 37  127.105355  36.810215
#
#     법정동
# 0   성거읍
# 1   신부동
# 2  원성1동
# 3  성정2동
# 4  불당2동

# %%
df = cafe.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#      Title                      Address   Longitude   Latitude   법정동
# 0     카페이숲  충남 천안시 서북구 성거읍 남창마을1길 32 1층  127.195422  36.862185   성거읍
# 1     블렌데렌     충남 천안시 동남구 먹거리8길 5 1, 2층         NaN        NaN   신부동
# 2  그리고스페셜티           충남 천안시 동남구 유량로 104  127.172754  36.807128  원성1동
# 3     오월의숲            충남 천안시 서북구 세관길 78  127.145208  36.823195  성정2동
# 4      유얼스          충남 천안시 서북구 불당31길 37  127.105355  36.810215  불당2동

# %%
df1 = df[df["법정동"]=='부성2동']

df1
# Out:
#          Title                                   Address   Longitude  \
# 9          마젠타                충남 천안시 서북구 성성2길 81 1동 2~4층  127.129597
# 15        그레이츄                        충남 천안시 서북구 오성7길 42  127.132561
# 30   애월빵 공장 천안  충남 천안시 서북구 성성5로 95 브이티스퀘어 비동 지층 112~118호  127.132566
# 48         릴리프                  충남 천안시 서북구 성성11길 24-1 1층  127.137297
# 82       카페르블랑                        충남 천안시 서북구 원두정6길 2  127.133549
# 116         시온                         충남 천안시 서북구 공단로 72  127.126630
# 120        블랙문                    충남 천안시 서북구 원두정7길 25 1층  127.136828
# 122      977번지                     충남 천안시 서북구 부성4길 10 2층  127.135178
# 149   플러피 디저트샵           충남 천안시 서북구 성성동 40-16 수변로 1층 플러피  127.136467
# 162     더모어더베러        충남 천안시 서북구 3공단6로 50 힐링제이타워 1층 116호  127.103177
# 178        마농스                    충남 천안시 서북구 원두정8길 15 1층  127.135053
# 185      블루더카페                     충남 천안시 서북구 동서대로 53 1층  127.129273
# 189     마르페 커피                     충남 천안시 서북구 노태산로 98 1층  127.127643
# ...

# %%
df1.to_csv('부성2동.csv', encoding = "utf-8")

# %%
df2 = df[df["법정동"]=='부성1동']

df2.to_csv('부성1동.csv', encoding = "utf-8")

# %%
df3 = df[df["법정동"]=='청룡동']

df3.to_csv('청룡동.csv', encoding = "utf-8")

# %%
df4 = df[df["법정동"]=='신안동']

df4.to_csv('신안동.csv', encoding = "utf-8")

# %%
df5 = df[df["법정동"]=='신방동']

df5.to_csv('신방동.csv', encoding = "utf-8")
